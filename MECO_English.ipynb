# %%
# imports
import pandas as pd

# %%
# import csv as pandas dataframe
df = pd.read_csv("osfstorage-archive/release 1.0/version 1.2/auxiliary files/reading task materials/supp texts.csv")

# %%
# change the title of the first column to langauge
df = df.rename(columns = {"Unnamed: 0": "language"})
# remove the two rightmost columns
df = df.iloc[:, :-2]
# remove all rows after 12
df = df.iloc[:13, :]
df.head()
# Out:
#    language                                              Janus  \
# 0     Dutch  Janus is in de oude Romeinse religie en mythes...
# 1   English  In ancient Roman religion and myth, Janus is t...
# 2  Estonian  Janus oli vanarooma religioonis ja mütoloogias...
# 3   Finnish  Muinaisen roomalaisen mytologian mukaan Janus ...
# 4    German  In der alten römischen Religion und Mythologie...
#
#                                                Shaka  \
# 0  Het shaka-teken, ook bekend als ‘laat het los’...
# 1  The shaka sign, sometimes known as hang loose"...
# 2  Shaka märki seostatakse üldiselt Havai ja surf...
# 3  Shaka-merkin merkitys liittyy ystävällisyyteen...
# 4  Das Wort Shaka, begleitet von einer typischen ...
#
#                                               Doping  \
# 0  Doping is het gebruik van verboden prestatiebe...
# 1  In competitive sports, doping is the use of ba...
# 2  Doping on spordis reeglitevastane aine, mida k...
# 3  Kilpaurheilussa doping tarkoittaa kilpailevien...
# 4  Im Leistungssport ist Doping die Nutzung verbo...
#
#                                            Thylacine  \
# 0  De buidelwolf was een van de grotere vleeseten...
# 1  The thylacine was the largest known carnivorou...
# 2  Kukkurhunt on kiskeluviisiga kukkurloom, keda ...
# 3  Pussihukka oli uuden ajan suurin lihansyöjäpus...
# 4  Der Beutelwolf, auch Tasmanischer Tiger genann...
#
#                                World Environment Day  \
# 0  De wereldmilieudag wordt sinds 1974 jaarlijks ...
# 1  World Environment Day (WED) is celebrated on t...
# 2  Ülemaailmset keskkonnapäeva tähistatakse igal ...
# 3  Maailman ympäristöpäivä on vuodesta 1974 alkae...
# 4  Der Weltumwelttag oder auch Tag der Umwelt ist...
#
#                                             Monocole  \
# 0  Een monocle of oogglas is een halve bril, dat ...
# 1  A monocle is a type of corrective lens used to...
# 2  Monokkel on nägemise korrigeerimiseks mõeldud ...
# 3  Monokkeli on optinen linssi, joka asetetaan to...
# 4  Das Monokel ist eine Sehhilfe, die im Gegensat...
#
#                                         Wine Tasting  \
# 0  Wijnproeven is het sensorisch onderzoeken en b...
# 1  Wine tasting is the sensory examination and ev...
# 2  Veini degusteerimine on veini sensoorne uurimi...
# 3  Viininmaistelu on viinin aistinvaraista tarkas...
# 4  Eine Weinprobe ist die sensorische Prüfung und...
#
#                                         Orange Juice  \
# 0  Sinaasappelsap is een vruchtensap verkregen do...
# 1  Orange juice is a liquid extract of the orange...
# 2  Apelsinimahl on vedelik, mis on saadud apelsin...
# 3  Appelsiinimehu on tuoreista appelsiineista pur...
# 4  Orangensaft ist ein Fruchtsaft, der durch Ausp...
#
#                                           Beekeeping  \
# 0  Een imker is iemand die zich bezighoudt met de...
# 1  Beekeeping is the maintenance of bee colonies ...
# 2  Mesindus on mesilaste pidamine mesindussaadust...
# 3  Mehiläishoito tarkoittaa mehiläisten kasvatust...
# 4  Der Imker beschäftigt sich mit der Haltung, Ve...
#
#                                        National Flag
# 0  Een nationale vlag is een vlag die een land ve...
# 1  A national flag is a flag which represents and...
# 2  Riigilipp on lipp, mis tähistab riiki ja on se...
# 3  Kansallislippu on lippu, joka edustaa valtiota...
# 4  Eine Nationalflagge symbolisiert als Flagge ei...

# %%
eng = df[df['language'] == 'English']
# Out:
#   language                                              Janus  \
# 1  English  In ancient Roman religion and myth, Janus is t...
#
#                                                Shaka  \
# 1  The shaka sign, sometimes known as hang loose"...
#
#                                               Doping  \
# 1  In competitive sports, doping is the use of ba...
#
#                                            Thylacine  \
# 1  The thylacine was the largest known carnivorou...
#
#                                World Environment Day  \
# 1  World Environment Day (WED) is celebrated on t...
#
#                                             Monocole  \
# 1  A monocle is a type of corrective lens used to...
#
#                                         Wine Tasting  \
# 1  Wine tasting is the sensory examination and ev...
#
#                                         Orange Juice  \
# 1  Orange juice is a liquid extract of the orange...
#
#                                           Beekeeping  \
# 1  Beekeeping is the maintenance of bee colonies ...
#
#                                        National Flag
# 1  A national flag is a flag which represents and...
